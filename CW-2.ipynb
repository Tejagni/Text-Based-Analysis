# %% [markdown]
# ## Reading the CSV File and Displaying the DataFrame!

# %%
# importing pandas library
import pandas as pd

# Giving the path of the CSV file and stored in a variable name file
file = "C:\\Users\\himav\\Downloads\\un-general-debates-blueprint.csv"

# Reading the CSV file and stored in a variable named called dataframe(df)
df = pd.read_csv(file)

# Printing the first 20 rows of the data from the CSV file
df.head(20)
# Out:
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# ...

# %% [markdown]
# ## Columns

# %%
# Prinitng the column names for an overview
df.columns
# Out:
# Index(['session', 'year', 'country', 'country_name', 'speaker', 'position',
#        'text'],
#       dtype='object')

# %% [markdown]
# ## dtypes

# %%
# Printing the data types of the columns
df.dtypes
# Out:
# session          int64
# year             int64
# country         object
# country_name    object
# speaker         object
# position        object
# text            object
# dtype: object

# %% [markdown]
# ## info()

# %%
# Printing the information for an overview
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7507 entries, 0 to 7506
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   session       7507 non-null   int64
#  1   year          7507 non-null   int64
#  2   country       7507 non-null   object
#  3   country_name  7507 non-null   object
#  4   speaker       7480 non-null   object
#  5   position      4502 non-null   object
#  6   text          7507 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 410.7+ KB

# %% [markdown]
# ## describe()

# %%
# Describing the data of the CSV File
df.describe()
# Out:
#            session         year
# count  7507.000000  7507.000000
# mean     49.610763  1994.610763
# std      12.892155    12.892155
# min      25.000000  1970.000000
# 25%      39.000000  1984.000000
# 50%      51.000000  1996.000000
# 75%      61.000000  2006.000000
# max      70.000000  2015.000000

# %% [markdown]
# ## New Column with the Length of the “text” Column

# %%
# Adding a new column with the length of the “text” column
df['length'] = df['text'].str.len()

# Describing the output
df.describe()
# Out:
#            session         year        length
# count  7507.000000  7507.000000   7507.000000
# mean     49.610763  1994.610763  17967.281604
# std      12.892155    12.892155   7860.038463
# min      25.000000  1970.000000   2362.000000
# 25%      39.000000  1984.000000  12077.000000
# 50%      51.000000  1996.000000  16424.000000
# 75%      61.000000  2006.000000  22479.500000
# max      70.000000  2015.000000  72041.000000

# %% [markdown]
# ## Text Field

# %%
# Using the Describe method
df.describe(include='O')
# Out:
#        country country_name        speaker                      position  \
# count     7507         7507           7480                          4502
# unique     199          199           5428                           113
# top        ALB      Albania  Seyoum Mesfin  Minister for Foreign Affairs
# freq        46           46             12                          1813
#
#                                                      text
# count                                                7507
# unique                                               7507
# top     33: May I first convey to our President the co...
# freq                                                    1

# %% [markdown]
# ## Check for Missing Data

# %%
# Checking for missing data
df.isna().sum()
# Out:
# session            0
# year               0
# country            0
# country_name       0
# speaker           27
# position        3005
# text               0
# length             0
# dtype: int64

# %% [markdown]
# ##  Fill the Missing Data

# %%
# Filling the missing data in the column speaker
df['speaker'].fillna('unknown', inplace=True)

#Filling the missing data in the column position
df['position'].fillna('unknown', inplace=True)
df.isna().sum()
# Out:
# session         0
# year            0
# country         0
# country_name    0
# speaker         0
# position        0
# text            0
# length          0
# dtype: int64

# %% [markdown]
# ## Uppercase (or Lowercase) 'Speaker' Column

# %%
# Converting and printing the speaker column data into uppercase using upper() method
df['speaker'] = df['speaker'].str.upper()
df
# Out:
#       session  year country  country_name                            speaker  \
# 0          25  1970     ALB       Albania                            MR. NAS
# 1          25  1970     ARG     Argentina                 MR. DE PABLO PARDO
# 2          25  1970     AUS     Australia                        MR. MCMAHON
# 3          25  1970     AUT       Austria                 MR. KIRCHSCHLAEGER
# 4          25  1970     BEL       Belgium                         MR. HARMEL
# ...       ...   ...     ...           ...                                ...
# 7502       70  2015     YEM         Yemen  MR. ABDRABUH MANSOUR HADI MANSOUR
# 7503       70  2015     YUG    Yugoslavia               MR. TOMISLAV NIKOLIĆ
# 7504       70  2015     ZAF  South Africa                         JACOB ZUMA
# 7505       70  2015     ZMB        Zambia             MR. EDGAR CHAGWA LUNGU
# 7506       70  2015     ZWE      Zimbabwe                      ROBERT MUGABE
#
# ...

# %% [markdown]
# ## Uppercase (or Lowercase) 'Position' Column

# %%
# Converting and printing the position column data into uppercase using upper() method
df['position'] = df['position'].str.upper()
df
# Out:
#       session  year country  country_name                            speaker  \
# 0          25  1970     ALB       Albania                            MR. NAS
# 1          25  1970     ARG     Argentina                 MR. DE PABLO PARDO
# 2          25  1970     AUS     Australia                        MR. MCMAHON
# 3          25  1970     AUT       Austria                 MR. KIRCHSCHLAEGER
# 4          25  1970     BEL       Belgium                         MR. HARMEL
# ...       ...   ...     ...           ...                                ...
# 7502       70  2015     YEM         Yemen  MR. ABDRABUH MANSOUR HADI MANSOUR
# 7503       70  2015     YUG    Yugoslavia               MR. TOMISLAV NIKOLIĆ
# 7504       70  2015     ZAF  South Africa                         JACOB ZUMA
# 7505       70  2015     ZMB        Zambia             MR. EDGAR CHAGWA LUNGU
# 7506       70  2015     ZWE      Zimbabwe                      ROBERT MUGABE
#
# ...

# %% [markdown]
# ## Uppercase (or Lowercase) 'text' Column

# %%
# Converting and printing the text column data into uppercase using upper() method
df['text'] = df['text'].str.upper()
df
# Out:
#       session  year country  country_name                            speaker  \
# 0          25  1970     ALB       Albania                            MR. NAS
# 1          25  1970     ARG     Argentina                 MR. DE PABLO PARDO
# 2          25  1970     AUS     Australia                        MR. MCMAHON
# 3          25  1970     AUT       Austria                 MR. KIRCHSCHLAEGER
# 4          25  1970     BEL       Belgium                         MR. HARMEL
# ...       ...   ...     ...           ...                                ...
# 7502       70  2015     YEM         Yemen  MR. ABDRABUH MANSOUR HADI MANSOUR
# 7503       70  2015     YUG    Yugoslavia               MR. TOMISLAV NIKOLIĆ
# 7504       70  2015     ZAF  South Africa                         JACOB ZUMA
# 7505       70  2015     ZMB        Zambia             MR. EDGAR CHAGWA LUNGU
# 7506       70  2015     ZWE      Zimbabwe                      ROBERT MUGABE
#
# ...

# %% [markdown]
# ## Speakers with ‘BUSH’ in them

# %%
# Printing the data contains 'BUSH' in speaker column
df[df['speaker'].str.contains('BUSH')]
# Out:
#       session  year country   country_name             speaker   position  \
# 2720       44  1989     USA  United States                BUSH  PRESIDENT
# 2876       45  1990     USA  United States         GEORGE BUSH    UNKNOWN
# 3038       46  1991     USA  United States         GEORGE BUSH  PRESIDENT
# 3207       47  1992     USA  United States     MR. GEORGE BUSH  PRESIDENT
# 4814       56  2001     USA  United States      GEORGE W. BUSH  PRESIDENT
# 5002       57  2002     USA  United States  MR. GEORGE W. BUSH  PRESIDENT
# 5191       58  2003     USA  United States      GEORGE W. BUSH  PRESIDENT
# 5382       59  2004     USA  United States   MR. GEORGE W BUSH  PRESIDENT
# 5760       61  2006     USA  United States  MR. GEORGE W. BUSH  PRESIDENT
# 5951       62  2007     USA  United States      GEORGE W. BUSH  PRESIDENT
# 6143       63  2008     USA  United States      GEORGE W. BUSH  PRESIDENT
#
#                                                    text  length
# ...

# %% [markdown]
# ## Charts

# %%
# Plotting the Graph
df['length'].plot()
# Out:
# <Axes: >

# %%
# Plotting the length graph in a kind of box in the horizontal position 
df['length'].plot(kind='box', vert=False)
# Out:
# <Axes: >

# %% [markdown]
# ## Histogram

# %%
# Plotting the histogram Graph labelling Y-axis as Frequency
df['length'].plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Bar plot

# %%
# Printing the Bar Plot taking X-axis as 'Country' and Y-axis as 'Length'
import seaborn as sns
where = df['country'].isin(['USA', 'FRA', 'GBR', 'CHN', 'RUS'])
g = sns.catplot(data=df[where], x="country", y="length", kind='box')
g.fig.set_size_inches(10, 8) ###
# Out:
# C:\Users\himav\.anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Function to tokenize

# %%
# Tokenizing a Function using a function tokenize()
import regex as re
def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

x = tokenize('hima Varshini')
print(x)
# Out:
# ['hima', 'Varshini']

# %% [markdown]
# ## Example

# %%
# Try it out before running it on the whole dataset
testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov"
testtokens = tokenize(testtext)
print(testtokens)
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', 'www', 'cdc', 'gov']

# %% [markdown]
# ## Remove stop words

# %%
# We will use the list of English stop words that are standard in python
import nltk
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'before', 'will', 'own', "shan't", 'me', 'don', 'who', 'itself', 'ourselves', "it's", 'yours', 'can', 'them', 'mustn', 'if', 'an', 'which', "you're", 'in', 'so', 'hadn', "shouldn't", 'and', 'below', 'on', 'against', 'until', 'he', 'mightn', 'few', 'of', 'y', "wouldn't", 'didn', 'under', 'it', "aren't", "wasn't", 'are', 'hasn', 'his', 'her', 's', 'themselves', 'over', 'were', 'their', "don't", "mustn't", 'whom', "couldn't", 'that', 'between', "haven't", 'most', "she's", "should've", 'haven', 'ain', 'had', 'than', 'at', 'having', 't', 'ma', 'out', 'him', 'some', 'doesn', 'has', 'couldn', 'being', 'off', "didn't", 'why', 'there', 'not', 'been', 'do', 'this', 'then', "you'd", 'no', 'she', 'where', "that'll", 'just', "you've", 'down', 'll', 'nor', 'same', 'isn', 'weren', "you'll", 'herself', 'yourself', 'the', 'your', 'myself', 'was', 'such', 'won', "isn't", 'after', 'during', 'very', 'shouldn', 'its', 'through', 'more', 'other', 've', 'what', 'theirs', 'while', 'you', 'too', 'all', 'bec
# ...

# %% [markdown]
# ## Function to remove stop words

# %%
# Removing the stop words using a function remove_stop()
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]

#Just testing it
cleantokens= remove_stop(testtokens)
print(cleantokens)
# Out:
# ['Let', 'defeat', 'SARS-CoV-2', 'together', 'www', 'cdc', 'gov']

# %% [markdown]
# ## Let’s make a “pipeline”

# %%
# Making a Pipeline
pipeline = [str.lower, tokenize, remove_stop]
def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %% [markdown]
# ## Run the pipeline

# %%
# Running a pipeline
df['tokens'] = df['text'].apply(prepare, pipeline=pipeline)

# %% [markdown]
# ## Count the tokens

# %%
# Counting the number of tokens using length method
df['num_tokens'] = df['tokens'].map(len)
df.tail()
# Out:
#       session  year country  country_name                            speaker  \
# 7502       70  2015     YEM         Yemen  MR. ABDRABUH MANSOUR HADI MANSOUR
# 7503       70  2015     YUG    Yugoslavia               MR. TOMISLAV NIKOLIĆ
# 7504       70  2015     ZAF  South Africa                         JACOB ZUMA
# 7505       70  2015     ZMB        Zambia             MR. EDGAR CHAGWA LUNGU
# 7506       70  2015     ZWE      Zimbabwe                      ROBERT MUGABE
#
#        position                                               text  length  \
# 7502  PRESIDENT  ON BEHALF OF THE PEOPLE AND THE GOVERNMENT OF ...   10568
# 7503  PRESIDENT  \nSEVENTY YEARS HAVE PASSED SINCE THE ESTABLIS...   25430
# 7504  PRESIDENT  I SHOULD LIKE TO CONGRATULATE THE PRESIDENT AN...   13662
# 7505  PRESIDENT  I WOULD LIKE TO BEGIN BY THANKING THE SECRETAR...   14247
# 7506  PRESIDENT  ALLOW ME AT THE OUTSET TO EXTEND TO MR. MOGENS...   11013
#
# ...

# %% [markdown]
# ## Use the “Counter”

# %%
# Using the Counter method
from collections import Counter

tokens = tokenize("She likes my cats and my cats like my sofa.")
testcount= Counter(tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %% [markdown]
# ## Add new data to the current count

# %%
# Adding the new data to the current count
more_tokens = tokenize("She likes dogs and cats.")
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %% [markdown]
# ## Let’s count

# %%
# Counting the most common 5 tokens using map() method
counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [('nations', 124508), ('united', 120763), ('international', 117223), ('world', 89421), ('countries', 85734)]

# %% [markdown]
# ## put the word frequency in it’s own dataframe for analysis

# %%
# put the word frequency in it’s own dataframe for analysis
freq_df = pd.DataFrame.from_dict(counter,orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'

# %% [markdown]
# ## Sort and display!

# %%
# Sorting and Displaying 10 values of the frequency dataframe
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#                  freq
# token
# nations        124508
# united         120763
# international  117223
# world           89421
# countries       85734
# peace           72625
# development     62632
# states          59713
# people          59338
# security        58425

# %% [markdown]
# ## Stats!

# %%
# Describing the data of the frequency dataframe
freq_df.describe()
# Out:
#                 freq
# count   68302.000000
# mean      162.686276
# std      1544.080072
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%        15.000000
# max    124508.000000

# %% [markdown]
# ## Bar chart

# %%
# plotting top 15 frequency dataframe names in the Y-axis named Token
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8))
ax.invert_yaxis()

# Taking X-axis as 'Frequency', Y-axis as 'Token' and title as 'Top Words'
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %% [markdown]
# ## Pip Installation

# %%
# Installing wordcloud
# !pip install wordcloud

# %% [markdown]
# ## Word Cloud

# %%
# Importing libraries wordcloud and matplotlib
from wordcloud import WordCloud
from matplotlib import pyplot as plt

# Printing output with the needy requirements
text = df.query("year==2015 and country=='USA'")['text'].values[0]

# Increase figsize and adjust WordCloud parameters
plt.figure(figsize=(18, 9))  # Increase figsize for larger initial image
wc = WordCloud(max_words=100, stopwords=stopwords, scale=5, max_font_size=80, min_font_size=10)  # Adjust scale and font sizes
wc.generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")

# Save the word cloud as a high-resolution image
plt.savefig('wordcloud_highres.png', dpi=600)  # Increase DPI further
plt.show()

# %% [markdown]
# ## All Data Word Cloud

# %%
wc = WordCloud(background_color='white', width = 800, height=800,
max_words=100, margin=2)
wc.fit_words(freq_df['freq'].to_dict() )
plt.figure(figsize = (10, 10), facecolor = None)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
